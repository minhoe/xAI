# %%
from keras.applications.inception_v3 import InceptionV3
from keras.applications.inception_v3 import preprocess_input
from keras.applications.inception_v3 import decode_predictions
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img

from keras.models import Model
from keras.layers import Dense, GlobalAveragePooling2D
from keras import backend as K

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/matplotlib/font_manager.py:278: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   'Matplotlib is building the font cache using fc-list. '

# %%
# create the base pre-trained model
base_model = InceptionV3(weights='imagenet', include_top=True)
# Out:
# Downloading data from https://github.com/fchollet/deep-learning-models/releases/download/v0.5/inception_v3_weights_tf_dim_ordering_tf_kernels.h5
# 96116736/96112376 [==============================] - 5s 0us/step

# %% [markdown]
# ### Loading images

# %%
import glob

file_list = glob.glob("./Images/*")
print(file_list)

img_list = []

for img_file in file_list:
    img = load_img(img_file)
    x = img_to_array(img)  # this is a Numpy array with shape (3(RGB), width, height)
    x = np.expand_dims(x, axis=0) # this is a Numpy array with shape (1, 3(RGB), width, height)
    #x = preprocess_input(x)
    print(x.shape)
    img_list.append(x)

img_list = np.array(img_list[0])
print('X_data shape:', img_list.shape)
# Out:
# ['./Images/bird.jpeg', './Images/cat.jpeg', './Images/elephant.jpeg', './Images/dog.jpeg']
# (1, 156, 324, 3)
# (1, 168, 300, 3)
# (1, 194, 260, 3)
# (1, 168, 300, 3)
# X_data shape: (1, 156, 324, 3)

# %%
data_gen = ImageDataGenerator(rescale=1./255)
input_data_gen = data_gen.flow_from_directory('/home/ubuntu/git-repos/xAI/xAI_LIME/Images',
                                            target_size = (299, 299),
                                              batch_size=1,
                                             shuffle=False)

filenames = input_data_gen.filenames
nb_samples = len(filenames)
print(filenames, nb_samples)
print(input_data_gen.class_indices)
# Out:
# Found 4 images belonging to 5 classes.
# ['bird/bird.jpeg', 'cat/cat.jpeg', 'dog/dog.jpeg', 'elephant/elephant.jpeg'] 4
# {'.ipynb_checkpoints': 0, 'bird': 1, 'cat': 2, 'dog': 3, 'elephant': 4}

# %%
preds = base_model.predict_generator(input_data_gen, steps=nb_samples)

for idx, x in enumerate(decode_predictions(preds, top=1)):
    print(x, filenames[idx])
# Out:
# [('n02027492', 'red-backed_sandpiper', 0.081805505)] bird/bird.jpeg
# [('n02123045', 'tabby', 0.5448355)] cat/cat.jpeg
# [('n02099601', 'golden_retriever', 0.8402856)] dog/dog.jpeg
# [('n02504013', 'Indian_elephant', 0.6565038)] elephant/elephant.jpeg

# %% [markdown]
# ### LIME explanation

# %%
from lime import lime_image
import time

# %%
explainer = lime_image.LimeImageExplainer()

# %%
def predict_fn(output):
    return output[0][2]

for idx, x in enumerate(decode_predictions(preds, top=1)):
    print(x, predict_fn(x), filenames[idx])
# Out:
# [('n02027492', 'red-backed_sandpiper', 0.081805505)] 0.081805505 bird/bird.jpeg
# [('n02123045', 'tabby', 0.5448355)] 0.5448355 cat/cat.jpeg
# [('n02099601', 'golden_retriever', 0.8402856)] 0.8402856 dog/dog.jpeg
# [('n02504013', 'Indian_elephant', 0.6565038)] 0.6565038 elephant/elephant.jpeg

# %%
import time

tgt_img = load_img('./Images/elephant/elephant.jpeg')
plt.imshow(tgt_img)
x = img_to_array(tgt_img)  # this is a Numpy array with shape (3(RGB), width, height)
x = np.expand_dims(x, axis=0) # this is a Numpy array with shape (1, 3(RGB), width, height)
pred = base_model.predict(x)

tmp = time.time()
# Hide color is the color for a superpixel turned OFF. Alternatively, if it is NONE, the superpixel will be replaced by the average of its pixels
explanation = explainer.explain_instance(x*1./255, base_model.predict, top_labels=5, hide_color=0, num_samples=1000)

print(time.time() - tmp)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-157-af7ac49f0beb> in <module>()
#       9 tmp = time.time()
#      10 # Hide color is the color for a superpixel turned OFF. Alternatively, if it is NONE, the superpixel will be replaced by the average of its pixels
# ---> 11 explanation = explainer.explain_instance(x*1./255, base_model.predict, top_labels=5, hide_color=0, num_samples=1000)
#      12 print(time.time() - tmp)
#
# ~/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/lime/lime_image.py in explain_instance(self, image, classifier_fn, labels, hide_color, top_labels, num_features, num_samples, batch_size, segmentation_fn, distance_metric, model_regressor, random_seed)
#     167                                                     random_seed=random_seed)
#     168         try:
# --> 169             segments = segmentation_fn(image)
#     170         except ValueError as e:
#     171             raise e
#
# ~/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/lime/wrappers/scikit_image.py in __call__(self, *args)
#     115
#     116     def __call__(self, *args):
# --> 117             return self.target_fn(args[0], **self.target_params)
#
# ~/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/skimage/segmentation/_quickshift.py in quickshift(image, ratio, kernel_size, max_dist, return_tree, sigma, convert2lab, random_seed)
#      66         raise ValueError("`kernel_size` should be >= 1.")
#      67
# ---> 68     image = ndi.gaussian_filter(image, [sigma, sigma, 0])
#      69     image = np.ascontiguousarray(image * ratio)
#      70
#
# ~/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/scipy/ndimage/filters.py in gaussian_filter(input, sigma, order, output, mode, cval, truncate)
#     276     output = _ni_support._get_output(output, input)
#     277     orders = _ni_support._normalize_sequence(order, input.ndim)
# --> 278     sigmas = _ni_support._normalize_sequence(sigma, input.ndim)
#     279     modes = _ni_support._normalize_sequence(mode, input.ndim)
#     280     axes = list(range(input.ndim))
#
# ~/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/scipy/ndimage/_ni_support.py in _normalize_sequence(input, rank)
#      63         if len(normalized) != rank:
#      64             err = "sequence argument must have length equal to input rank"
# ---> 65             raise RuntimeError(err)
#      66     else:
#      67         normalized = [input] * rank
#
# RuntimeError: sequence argument must have length equal to input rank
